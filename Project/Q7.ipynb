# %%
import requests

url = "https://cricbuzz-cricket.p.rapidapi.com/stats/v1/topstats/0"

querystring = {"statsType":"mostRuns","matchType":"1"}

headers = {
	"x-rapidapi-key": "3ef7637f88msh7d89f4a3bb674c8p177f68jsnd51f17c0fc42",
	"x-rapidapi-host": "cricbuzz-cricket.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

print(response.json())
o1_runs = response.json()
# Out:
# {'filter': {'matchtype': [{'matchTypeId': '1', 'matchTypeDesc': 'test'}, {'matchTypeId': '2', 'matchTypeDesc': 'odi'}, {'matchTypeId': '3', 'matchTypeDesc': 't20i'}], 'team': [{'id': '2', 'teamShortName': 'IND'}, {'id': '27', 'teamShortName': 'IRE'}, {'id': '3', 'teamShortName': 'PAK'}, {'id': '4', 'teamShortName': 'AUS'}, {'id': '5', 'teamShortName': 'SL'}, {'id': '6', 'teamShortName': 'BAN'}, {'id': '9', 'teamShortName': 'ENG'}, {'id': '10', 'teamShortName': 'WI'}, {'id': '11', 'teamShortName': 'RSA'}, {'id': '12', 'teamShortName': 'ZIM'}, {'id': '13', 'teamShortName': 'NZ'}, {'id': '96', 'teamShortName': 'AFG'}], 'selectedMatchType': 'test'}, 'headers': ['Batter', 'M', 'I', 'R', 'Avg'], 'values': [{'values': ['25', 'Tendulkar', '200', '329', '15921', '53.79']}, {'values': ['8019', 'Root', '163', '298', '13943', '51.07']}, {'values': ['38', 'R Ponting', '168', '287', '13378', '51.85']}, {'values': ['213', 'Kallis', '166', '280', '13289', '55.37']}, {'values': ['27', 'Dravid', '164'
# ...

# %%
import requests

url = "https://cricbuzz-cricket.p.rapidapi.com/stats/v1/topstats/0"

querystring = {"statsType":"mostRuns","matchType":"2"}

headers = {
	"x-rapidapi-key": "3ef7637f88msh7d89f4a3bb674c8p177f68jsnd51f17c0fc42",
	"x-rapidapi-host": "cricbuzz-cricket.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

print(response.json())
o2_runs = response.json()
# Out:
# {'filter': {'matchtype': [{'matchTypeId': '1', 'matchTypeDesc': 'test'}, {'matchTypeId': '2', 'matchTypeDesc': 'odi'}, {'matchTypeId': '3', 'matchTypeDesc': 't20i'}], 'team': [{'id': '2', 'teamShortName': 'IND'}, {'id': '27', 'teamShortName': 'IRE'}, {'id': '3', 'teamShortName': 'PAK'}, {'id': '4', 'teamShortName': 'AUS'}, {'id': '5', 'teamShortName': 'SL'}, {'id': '6', 'teamShortName': 'BAN'}, {'id': '9', 'teamShortName': 'ENG'}, {'id': '10', 'teamShortName': 'WI'}, {'id': '11', 'teamShortName': 'RSA'}, {'id': '12', 'teamShortName': 'ZIM'}, {'id': '13', 'teamShortName': 'NZ'}, {'id': '96', 'teamShortName': 'AFG'}], 'selectedMatchType': 'odi'}, 'headers': ['Batter', 'M', 'I', 'R', 'Avg'], 'values': [{'values': ['25', 'Tendulkar', '463', '452', '18426', '44.83']}, {'values': ['1413', 'Kohli', '311', '299', '14797', '58.72']}, {'values': ['104', 'Sangakkara', '404', '380', '14234', '41.99']}, {'values': ['38', 'R Ponting', '375', '365', '13704', '42.04']}, {'values': ['102', 'S Jayasur
# ...

# %%
import requests

url = "https://cricbuzz-cricket.p.rapidapi.com/stats/v1/topstats/0"

querystring = {"statsType":"mostRuns","matchType":"3"}

headers = {
	"x-rapidapi-key": "3ef7637f88msh7d89f4a3bb674c8p177f68jsnd51f17c0fc42",
	"x-rapidapi-host": "cricbuzz-cricket.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

print(response.json())
o3_runs = response.json()
# Out:
# {'filter': {'matchtype': [{'matchTypeId': '1', 'matchTypeDesc': 'test'}, {'matchTypeId': '2', 'matchTypeDesc': 'odi'}, {'matchTypeId': '3', 'matchTypeDesc': 't20i'}], 'team': [{'id': '2', 'teamShortName': 'IND'}, {'id': '27', 'teamShortName': 'IRE'}, {'id': '3', 'teamShortName': 'PAK'}, {'id': '4', 'teamShortName': 'AUS'}, {'id': '5', 'teamShortName': 'SL'}, {'id': '6', 'teamShortName': 'BAN'}, {'id': '9', 'teamShortName': 'ENG'}, {'id': '10', 'teamShortName': 'WI'}, {'id': '11', 'teamShortName': 'RSA'}, {'id': '12', 'teamShortName': 'ZIM'}, {'id': '13', 'teamShortName': 'NZ'}, {'id': '96', 'teamShortName': 'AFG'}], 'selectedMatchType': 't20i'}, 'headers': ['Batter', 'M', 'I', 'R', 'Avg'], 'values': [{'values': ['9163', 'Suzie Bates', '177', '174', '4716', '29.11']}, {'values': ['8359', 'Babar Azam', '141', '134', '4566', '39.36']}, {'values': ['576', 'Rohit', '159', '151', '4231', '32.05']}, {'values': ['1413', 'Kohli', '125', '117', '4188', '48.70']}, {'values': ['10012', 'Smriti M
# ...

# %%
test_data= o1_runs['values']
odi_data = o2_runs['values']
t20i_data = o3_runs['values']

# %%
formats = {
    "Test": test_data,
    "ODI": odi_data,
    "T20I": t20i_data
}

result = []

for format_name, data in formats.items():
    max_runs = 0
    top_player = None

    for row in data:
        runs = int(row['values'][4])
        player = row['values'][1]

        if runs > max_runs:
            max_runs = runs
            top_player = player

    result.append({
        'format': format_name,
        'player': top_player,
        'highest_score': max_runs
    })

# Output
for r in result:
    print(r['format'], r['player'], r['highest_score'])
# Out:
# Test Tendulkar 15921
# ODI Tendulkar 18426
# T20I Suzie Bates 4716
